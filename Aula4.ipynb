# %% [markdown]
# <a href="https://colab.research.google.com/github/felixetec/programacao/blob/main/Aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *ATIVIDADE* : Escrever um programa que recebe a temperatura em graus Celsius e converte para Fahrenheit
#
# # Entrada : graus celsius
#
# #Processamento
# F = C * (9/5) + 32
#
# #Saida
#
# mostrar graus Celsius em Fahrenheit

# %%
# Escrever um programa que recebe uma quantidade de graus Celsius e converter para Fahrenheit

#Entrada

c = float(input("digite a temperatura em graus celsius: "))

#Processamento

fahrenheit = c * (9 / 5) + 32

#Saída

print(f"A temperatura de firenheit é igual a: {fahrenheit}")
# Out:
# digite a temperatura em graus celsius: 12.12
# A temperatura de firenheit é igual a: 53.816

# %%
# Calcular a área do retângulo


#Entrada

comprimento = float (input("digite o comprimento: " ))
altura = float (input ("digite a altura: "))

#Processamento

área = comprimento * altura

#Saída

print (f"O total da área do retângulo é igual: {área}")
# Out:
# digite o comprimento: 12
# digite a altura: 3
# O total da área do retângulo é igual: 36.0

# %%
# Escrever um programa que faça cálculos aritiméticos

# Entrada

a = int (input(" digite o primeiro número: "))
b = int (input(" digite o segundo número: "))

# Processamento

soma = a + b
subtracao = a - b
multiplicacao = a * b
divisao = a / b
div_int = a // b
resto  = a % b # O símbolo da " % " é igual ao resto da divisão

#Saída

print("---------------CALCULADORA SIMPLES---------------")
print("")
print("---------------soma------------------------------")
print("")
print(f"O resultado da soma de {a} mais {b} é igual: {soma}")
print("")
print("---------------subtracao--------------------------")
print("")
print(f"O resultado da subtracao de {a} menos {b} é igual: {subtracao}")
print("")
print("---------------multiplicacao--------------------------")
print("")
print(f"O resultado da multiplicacao de {a} vezes {b} é igual: {multiplicacao}")
print("")
print("----------------------------------------------------")
print("")
print("---------------divisao--------------------------")
print("")
print(f"O resultado da divisao de {a} dividido {b} é igual: {divisao}")
print("")
print("-------------------------divisao int--------------------------")
print("")
print(f"O resultado da divisao de {a} dividido {b} é igual: {div_int}")
print("")
print("-----------------------------resto----------------------------")
print("")
print(f"O resto do resultado da divisao de {a} dividido {b} é igual: {resto}")
print("")
# Out:
#  digite o primeiro número: 25
#  digite o segundo número: 12
# ---------------CALCULADORA SIMPLES---------------
#
# ---------------soma------------------------------
#
# O resultado da soma de 25 mais 12 é igual: 37
#
# ---------------subtracao--------------------------
#
# O resultado da subtracao de 25 menos 12 é igual: 13
#
# ---------------multiplicacao--------------------------
#
# O resultado da multiplicacao de 25 vezes 12 é igual: 300
#
# ----------------------------------------------------
#
# ---------------divisao--------------------------
#
# O resultado da divisao de 25 dividido 12 é igual: 2.0833333333333335
#
# -------------------------divisao int--------------------------
#
# O resultado da divisao de 25 dividido 12 é igual: 2
#
# -----------------------------resto----------------------------
#
# O resto do resultado da divisao de 25 dividido 12 é igual: 1
